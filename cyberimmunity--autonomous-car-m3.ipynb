# %% [markdown]
# # Кибериммунная автономность$\\$Создание конструктивно защищённого автономного наземного транспортного средства$\\$Модуль 3
#
# ## О документе
#
# Версия 1.03
#
# Модуль 3 для регионального этапа соревнований по кибериммунной автономности

# %% [markdown]
# ### Модуль 3. Внедрение блоков функциональной и информационной безопасности
# #### Общая идея
#
# Ключевая идея кибериммунной автономности заключается в том, чтобы уже на этапе проектирования внедрить защиту от кибератак как снаружи, так и изнутри - т.е. через уязвимые бортовые информационные системы.
# Мы исходим из того, что абсолютно защищённых систем не бывает, чем больше и сложнее код, тем проще одним ("плохим") в нём спрятать уязвимости, а другим ("хорошим", но уставшим) эти уязвимости не найти.
#
# Поэтому необходимо сделать так, чтобы наиболее критичный код был отделён от некритичного и протестирован особенно тщательно - таким образом можно снизить вероятность успешной атаки и затруднить задачу атакующим.

# %% [markdown]
# #### Цели и предположения безопасности
#
# ##### Цели безопасности
# Устойчивость кибериммунных систем к атакам выражается в том, что поставленные заказчиком **цели безопасности** (ЦБ) не нарушаются даже в условиях кибератак (снаружи и изнутри).
#
# Для наших автономных машинок заказчиком поставлены следующие ЦБ:
#
# 1. При любых обстоятельствах АНТС осуществляет перемещения в пределах заданных ограничений
#
# 2. При любых обстоятельствах АНТС выполняет только аутентичный (подлинный) маршрут
#
# 3. При любых обстоятельствах АНТС оставляет груз только в авторизованном пункте назначения
#
# Ниже используется цифро-буквенное обозначение целей безопасности - например, ЦБ1 - первая цель безопасности из списка выше.
#
# ##### Предположения безопасности
# При этом заказчик согласовал с разработчиками следующие **предположения безопасности** (ПБ) - утверждения о смежных системах, которые снимают с разработчиков часть задач для обеспечения целей безопасности:
#
# 1. При любых обстоятельствах только авторизованный персонал имеет физический доступ к критическим узлам АНТС
#
# 2. При любых обстоятельствах только аутентичные и авторизованные операторы имеют доступ к системе планирования заданий
#
# 3. Аутентичные и авторизованные операторы обладают необходимой квалификацией и являются благонадёжными (т.е. не пытаются намеренно причинить ущерб системе или третьим лицам, используя доступ к АНТС)
#
# Ниже используется цифро-буквенное обозначение предположений безопасности - например, ПБ1 - первое предположение безопасности из списка выше.

# %% [markdown]
# ### Киберпрепятствия
#
# Прежде чем мы начнём внедрять механизмы безопасности, посмотрим, что произойдёт с нашей машинкой, если бортовые системы начнут вести себя не так, как мы ожидаем.
#
# Для этого активируем специальный режим работы системы управления и снова запустим машинку по тому же маршруту, который был в конце модуля 2.
#
# После инициализации системы управления добавьте следующую строку
# ```python
# control_system.enable_surprises()
# ```

# %% [markdown]
# Но вначале нужно из модуля 2 скопировать сюда ваши текущие наработки, а именно ваши реализации классов коммуникационного шлюза (CommunicationGateway), систему навигации (NavigationSystem), управления (ControlSystem), также будем использовать маршрут, который вы создали.

# %%
# from multiprocessing import Queue
# from src.communication_gateway import BaseCommunicationGateway
# from src.config import CONTROL_SYSTEM_QUEUE_NAME
# from src.event_types import Event

# class CommunicationGateway(BaseCommunicationGateway):
#     """CommunicationGateway класс для реализации логики взаимодействия
#     с системой планирования заданий

#     Работает в отдельном процессе, поэтому создаётся как наследник класса Process
#     """
#     def _send_mission_to_consumers(self):
#         """ метод для отправки сообщения с маршрутным заданием в систему управления """
        
#         # имена очередей блоков находятся в файле src/config.py
#         # события нужно отправлять в соответствие с диаграммой информационных потоков
#         control_q_name = CONTROL_SYSTEM_QUEUE_NAME

#         # события передаются в виде экземпляров класса Event, 
#         # описание класса находится в файле src/event_types.py
#         event = Event(source=BaseCommunicationGateway.event_source_name,
#                       destination=control_q_name,
#                       operation="set_mission", parameters=self._mission
#                       )

#         # поиск в каталоге нужной очереди (в данном случае - системы управления)
#         control_q: Queue = self._queues_dir.get_queue(control_q_name)
#         # отправка события в найденную очередь
#         control_q.put(event)

# from src.config import CONTROL_SYSTEM_QUEUE_NAME
# from src.navigation_system import BaseNavigationSystem

# class NavigationSystem(BaseNavigationSystem):
#     """ класс навигационного блока """
#     def _send_position_to_consumers(self):        
#         control_q_name = CONTROL_SYSTEM_QUEUE_NAME # замените на правильное название очереди
#         event = Event(
#             source=BaseNavigationSystem.event_source_name,
#             destination=control_q_name,
#             operation="position_update",
#             parameters=self._position           # Координаты текущего местоположения
#         )                                       # замените на код создания сообщения с координатами для системы управления 
#                                                 # подсказка, требуемая операция - position_update
#         control_q: Queue = self._queues_dir.get_queue(control_q_name)
#         control_q.put(event)

# from src.config import SERVOS_QUEUE_NAME
# from src.control_system import BaseControlSystem

# class ControlSystem(BaseControlSystem):
#     """ControlSystem блок расчёта управления """

#     def _send_speed_and_direction_to_consumers(self, speed, direction):
#         servos_q_name = SERVOS_QUEUE_NAME # замените на правильное название очереди
#         servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

#         # отправка сообщения с желаемой скоростью
#         event_speed = Event(
#             source=BaseControlSystem.event_source_name,
#             destination=servos_q_name,
#             operation="set_speed",
#             parameters=speed
#         )                   # замените на код создания сообщения со скоростью для приводов
#                             # подсказка, требуемая операция - set_speed

#         # отправка сообщения с желаемым направлением
#         event_direction = Event(
#             source=BaseControlSystem.event_source_name,
#             destination=servos_q_name,
#             operation="set_direction",
#             parameters=direction
#         )                       # замените на код создания сообщения с направлением для приводов
#                                 # подсказка, требуемая операция - set_direction

#         servos_q.put(event_speed)
#         servos_q.put(event_direction)

# %% [markdown]
# Если у вас настроена и работает СУПА, установите в True значение переменной afcs_present

# %%
afcs_present = True

# %% [markdown]
# Поменяем идентификатор машинки для этого модуля

# %%
car_id = "m3"

# %%
# используем то же маршрутное задание, которое было в модуле 2
from time import sleep
from geopy import Point as GeoPoint


from src.queues_dir import QueuesDirectory
from src.servos import Servos
from src.sitl import SITL
from src.cargo_bay import CargoBay
from src.mission_planner import MissionPlanner
from src.config import LOG_ERROR, LOG_INFO
from src.mission_planner_mqtt import MissionSender
from src.mission_planner import Mission
from src.sitl_mqtt import TelemetrySender
from src.system_wrapper import SystemComponentsContainer
from src.wpl_parser import WPLParser


# возьмём маршрут из модуля 2
wpl_file = "module2.wpl"

parser = WPLParser(wpl_file)    
points = parser.parse()
print(points)

from src.mission_type import GeoSpecificSpeedLimit
speed_limits = [
    GeoSpecificSpeedLimit(0, 20),
    GeoSpecificSpeedLimit(3, 60),
    GeoSpecificSpeedLimit(6, 20),
]

home = points[0]
mission = Mission(home=home, waypoints=points,speed_limits=speed_limits, armed=True)

# каталог очередей для передачи сообщений между блоками
queues_dir = QueuesDirectory() 

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

# mission_planner = MissionPlanner(
#     queues_dir, afcs_present=afcs_present, mission=mission)

# sitl = SITL(
#     queues_dir=queues_dir, position=home,
#     car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

# communication_gateway = CommunicationGateway(
#     queues_dir=queues_dir, log_level=LOG_ERROR)
# control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)

# navigation_system = NavigationSystem(
#     queues_dir=queues_dir, log_level=LOG_ERROR)

# servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
# cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

# # по аналогии собираем все блоки в одном кузове
# system_components = SystemComponentsContainer(
#     components=[
#         mission_sender,
#         telemetry_sender,
#         sitl,
#         mission_planner,
#         navigation_system,
#         servos,
#         cargo_bay,
#         communication_gateway,
#         control_system
#     ] if afcs_present else [
#         sitl,
#         mission_planner,
#         navigation_system,
#         servos,
#         cargo_bay,
#         communication_gateway,
#         control_system
#     ])

# #################################
# # АКТИВАЦИЯ КИБЕРПРЕПЯТСТВИЙ
# control_system.enable_surprises()
# #################################

# system_components.start()

# # ограничение поездки по времени
# # параметр sleep - время в секундах,
# # настройте этот параметр так, чтобы ваша машинка завершила маршрут
# # в случае превышения времени выполнения ячейки на более чем 10 секунд от заданного, 
# # допустимо перезапустить вычислительное ядро и повторно выполнить весь блокнот, штрафные очки за это не начисляются
# # при условии, что повторный запуск закончился успешно
# sleep(30)

# # останавливаем все компоненты
# system_components.stop()

# # удалим все созданные компоненты
# system_components.clean()
# del system_components
# Out:
# [Point(59.881527, 29.830053, 0.0), Point(59.881917, 29.82835, 0.0), Point(59.88183, 29.827888, 0.0), Point(59.881917, 29.827461, 0.0), Point(59.878108, 29.824056, 0.0), Point(59.876917, 29.829217, 0.0), Point(59.876699, 29.829021, 0.0), Point(59.876383, 29.828468, 0.0), Point(59.87634, 29.828693, 0.0), Point(59.876153, 29.828542, 0.0), Point(59.875639, 29.827471, 0.0), Point(59.87527, 29.827725, 0.0), Point(59.875166, 29.827532, 0.0), Point(59.875, 29.82782, 0.0), Point(59.875133, 29.828882, 0.0), Point(59.874685, 29.829965, 0.0), Point(59.874243, 29.829873, 0.0)]
# [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt

# %% [markdown]
# Итак, в отличие от, надеемся, успешного завершения маршрута в модуле 2, сейчас ваша машинка ведёт себя совсем иначе. Например, она внезапно едет в совершенно другую сторону (это особенно хорошо видно при использовании СУПА).
# И это ещё не всё, что может пойти не так..
#
# В этой реализации не очень много кода, теоретически, вы можете его весь изучить и устранить "незадокументированные возможности", однако в реальных системах кода гораздо больше. Например, кодовая база проекта с открытым исходным кодом ArduPilot, реализующего в том числе логику автопилота, составляет примерно миллион строк.
#
# Сколько времени вам понадобится, чтобы изучить и протестировать миллион строк кода? А ведь придётся проводить анализ и каждого обновления.. При этом неприятности могут быть хорошо спрятанными и на первый взгляд безобидными, вряд ли злоумышленники облегчат задачу и назовут свои изменения, например, "hacking_the_system" или "allowing_secret_remote_access". Вредоносный код может выглядеть совершенно безобидно или маскироваться под программный дефект.
#
# Поэтому тщательный анализ потребует большого количества ресурсов (человеческих, вычислительных, временныз), что стоит дорого.
#
# Логичным выходом является выделение критичных для целей безопасности проверок в отдельный блок, который протестировать должно быть гораздо проще.

# %% [markdown]
# #### Задания
#
# В этом модуле задание будет состоять из двух частей разной сложности:
#
# **3.1. добавить новый блок - "Ограничитель"** - этот модуль должен будет обеспечить соблюдение ограничений, указанных в маршрутном задании - это необходимо для обеспечения ЦБ1
#
# **З.2. *(задание повышенной сложности)* добавить монитор безопасности (МБ)** - он должен контролировать все взаимодействия *бортовых систем* (т.е. не включая планировщик и симулятор) и не давать блокам взаимодействовать друг с другом непредусмотренным образом - например, блок №5 может принимать команды только от №3, попытка передать команду в №5 от №2 должна блокироваться нашим монитором безопасности - потенциально это необходимо для обеспечения всех ЦБ

# %% [markdown]
# Для выполнения первой части задачи 3.1. необходимо для начала изменить архитектуру АНТС как показано на рис. 5
#
# ![Архитектура системы с ограничителем](images/ciac-arch-m31.png)
#
# Рис. 5. Архитектура АНТС с ограничителем (для ЦБ1)

# %% [markdown]
# Код базового класса Ограничителя находится в файле src/safety_block.py
#
# По аналогии с заданием в модуле 1, необходимо создать на основе этого класса свой собственный под названием SafetyBlock, в котором реализовать передачу команд в приводы движения, только перед эти необходимо ещё и проконтролировать их безопасность.
#
# Также необходимо реализовать передачу маршрутного задания из CommunicationGateway в SafetyBlock и координат из модуля Navigation в соответствии со стрелками на рис.5 выше.
#
# Если всё сделано правильно, то Ограничителю будет известно следующее
#
# - _mission - текущее маршрутное задание
# - _position - текущие координаты
#
# После проверки нужно установить значение внутренних переменных
# - _speed - текущая (допустимая) скорость
# - _direction - текущее (допустимое) направление
#
# Желательно завершить следование по маршруту. В критической ситуации, если продолжение маршрута невозможно, следует установить значение скорости и направления в 0, после чего передать эти команды в блок приводов (Servos)

# %% [markdown]
# Базовый сценарий для новой архитектуры можно представить следующим образом (см. рис. 6)
#
# ![Базовый сценарий с блоком безопасности](images/basic-scenario-with-safety-block1.png)
#
# Рис. 6. Базовый сценарий с блоком безопасности

# %% [markdown]
# Заготовка кода SafetyBlock
#
# ```python
# class SafetyBlock(BaseSafetyBlock):
#     """ класс ограничений безопасности """
#
#     def _set_new_direction(self, direction: float):
#         """ установка нового направления перемещения """
#         self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
#         self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
#         self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
#         # TODO реализовать контроль безопасности изменения направления
#         self._direction = direction
#         self._send_direction_to_consumers()
#
#     def _set_new_speed(self, speed: float):
#         """ установка новой скорости """
#         # TODO реализовать контроль безопасности изменения скорости
#         self._speed = speed
#         self._send_speed_to_consumers()
#
#
#     def _send_speed_to_consumers(self):
#         self._log_message(LOG_DEBUG, "отправляем скорость получателям")
#         servos_q_name = SERVOS_QUEUE_NAME
#         servos_q: Queue = self._queues_dir.get_queue(servos_q_name)
#
#         # отправка сообщения с желаемой скоростью
#         event_speed = Event(source=self.event_source_name,
#                             destination=servos_q_name,
#                             operation="set_speed",
#                             parameters=self._speed
#                             )
#         servos_q.put(event_speed)
#
#     def _send_direction_to_consumers(self):
#         self._log_message(LOG_DEBUG, "отправляем направление получателям")
#
#         servos_q_name = SERVOS_QUEUE_NAME
#         servos_q: Queue = self._queues_dir.get_queue(servos_q_name)
#
#         # отправка сообщения с желаемой скоростью
#         event_speed = Event(source=self.event_source_name,
#                             destination=servos_q_name,
#                             operation="set_direction",
#                             parameters=self._direction
#                             )
#         servos_q.put(event_speed)
# ```

# %%
from src.safety_block import BaseSafetyBlock
from src.config import LOG_DEBUG
from src.event_types import Event
from math import atan2, degrees, sin, cos, radians
from src.config import SERVOS_QUEUE_NAME, DEFAULT_LOG_LEVEL, CARGO_BAY_QUEUE_NAME, SAFETY_BLOCK_QUEUE_NAME

class SafetyBlock(BaseSafetyBlock):
    """ класс ограничений безопасности """

    def __init__(self, queues_dir: QueuesDirectory, log_level=DEFAULT_LOG_LEVEL):
            super().__init__(queues_dir, log_level)
            self._recalc_interval_sec = 0.1 
            self._tolerance_meters = 10

    def _set_new_direction(self, direction: float):
        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршрута: {self._route}")

        # if self._route.current_index == 0:
        #     self._lock_cargo()
        # elif self._route.route_finished:
        #     self._release_cargo()

        if self._mission and self._position and self._route and not self._route.route_finished:
            next_point = self._route.next_point()
            current_point = self._position
            desired_direction = self._calculate_bearing(current_point, next_point)
            tolerance = 0
            if not self._is_direction_allowed(direction, desired_direction, tolerance):
                self._log_message(LOG_ERROR, f"исправление: {direction} -> {desired_direction}")
                direction = desired_direction
                
        self._direction = direction
        self._send_direction_to_consumers()

    def _calculate_bearing(self, start, end):
        """Вычисляет направление между двумя точками."""
        lat1, lon1 = start.latitude, start.longitude
        lat2, lon2 = end.latitude, end.longitude
        
        self._log_message(LOG_DEBUG, f"Точка 1: ({lat1}, {lon1})")
        self._log_message(LOG_DEBUG, f"Точка 2: ({lat2}, {lon2})")

        d_lon = lon2 - lon1
        x = sin(radians(d_lon)) * cos(radians(lat2))
        y = cos(radians(lat1)) * sin(radians(lat2)) - \
            sin(radians(lat1)) * cos(radians(lat2)) * cos(radians(d_lon))
        bearing = atan2(x, y)
        bearing = degrees(bearing)
        bearing = (bearing + 360) % 360
        self._log_message(LOG_DEBUG, f"Рассчитанное направление: {bearing} градусов")
        return bearing

    def _is_direction_allowed(self, user_direction, desired_direction, tolerance):
        lower_bound = (desired_direction - tolerance) % 360
        upper_bound = (desired_direction + tolerance) % 360
        if lower_bound > upper_bound:
            return user_direction >= lower_bound or user_direction <= upper_bound
        return lower_bound <= user_direction <= upper_bound

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        if not self._mission or not self._position:
            self._log_message(LOG_DEBUG, "Неизвестный маршрут или позиция. Остановка.")
            speed = 0
        else:
            if speed < 0:
                self._log_message(LOG_DEBUG, f"Отрицательная скорость {speed} недопустима. Остановка.")
                speed = 0
            else:
                allowed_speed = self._route.calculate_speed()
                if allowed_speed is None:
                    self._log_message(LOG_DEBUG, "Не удалось определить допустимую скорость. Остановка.")
                    speed = 0
                elif speed > allowed_speed:
                    self._log_message(LOG_INFO, f"Скорость {speed} превышает лимит {allowed_speed}. Ограничиваем.")
                    speed = allowed_speed
        self._speed = speed
        self._send_speed_to_consumers()

    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed
                            )
        servos_q.put(event_speed)

    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем направление получателям")

        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_direction",
                            parameters=self._direction
                            )
        servos_q.put(event_speed)

    def _lock_cargo(self, _):
        """ заблокировать грузовой отсек """
        cargo_q = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        # инициализация сообщения с командой на блокировку грузового отсека
        # подсказка: блок CargoBay ожидает команду "lock_cargo" без параметров
        # self._log_message(LOG_DEBUG, "заблокировали грузовой отсек")
        event = Event(source=SAFETY_BLOCK_QUEUE_NAME,
                        destination=CARGO_BAY_QUEUE_NAME,
                        operation="lock_cargo", parameters= None
                        ) # <-- измените эту строку!
        cargo_q.put(event)

    def _release_cargo(self, _):
        """ открыть грузовой отсек """
        self._log_message(LOG_INFO, "попытка открыть грузовой отсек")
        if self._route and not self._route.route_finished:
            self._log_message(LOG_ERROR, "пресечена попытка открыть грузовой отсек")
            return
        cargo_q = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        # инициализация сообщения с командой на блокировку грузового отсека
        # подсказка: блок CargoBay ожидает команду "release_cargo" без параметров
        # self._log_message(LOG_DEBUG, "грузовой отсек разблокирован")
        event = Event(source=SAFETY_BLOCK_QUEUE_NAME,
                        destination=CARGO_BAY_QUEUE_NAME,
                        operation="release_cargo", parameters= None
                        ) # <-- измените эту строку!
        cargo_q.put(event)

# %%
# 2. напишите в этом блоке реализацию изменённых блоков связи, управления и навигации, 
# чтобы передавать данные согласно изменённой архитектуре на рис. 5 для обеспечения работы по сценарию на рис.6

from multiprocessing import Queue
from src.communication_gateway import BaseCommunicationGateway
from src.config import CONTROL_SYSTEM_QUEUE_NAME, SAFETY_BLOCK_QUEUE_NAME
from src.event_types import Event
from src.control_system import BaseControlSystem
from src.config import CONTROL_SYSTEM_QUEUE_NAME
from src.navigation_system import BaseNavigationSystem

class CommunicationGateway(BaseCommunicationGateway):
    """CommunicationGateway класс для реализации логики взаимодействия
    с системой планирования заданий

    Работает в отдельном процессе, поэтому создаётся как наследник класса Process
    """
    def _send_mission_to_consumers(self):
        """ метод для отправки сообщения с маршрутным заданием в систему управления """
        # имена очередей блоков находятся в файле src/config.py
        # события нужно отправлять в соответствие с диаграммой информационных потоков
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME

        # события передаются в виде экземпляров класса Event, 
        # описание класса находится в файле src/event_types.py
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        # поиск в каталоге нужной очереди (в данном случае - системы управления)
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        # отправка события в найденную очередь
        control_q.put(event)
        safety_block_q_name = SAFETY_BLOCK_QUEUE_NAME
        # события передаются в виде экземпляров класса Event, 
        # описание класса находится в файле src/event_types.py
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=safety_block_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        # поиск в каталоге нужной очереди (в данном случае - системы управления)
        safety_block__q: Queue = self._queues_dir.get_queue(safety_block_q_name)
        # отправка события в найденную очередь
        safety_block__q.put(event)

class ControlSystem(BaseControlSystem):
    """ControlSystem блок расчёта управления """
    def _send_speed_and_direction_to_consumers(self, speed, direction):
        safety_block_q_name = SAFETY_BLOCK_QUEUE_NAME # замените на правильное название очереди
        safety_block_q: Queue = self._queues_dir.get_queue(safety_block_q_name)
        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=safety_block_q_name,
                      operation="set_speed", parameters=speed
                      ) # замените на код создания сообщения со скоростью для приводов
                           # подсказка, требуемая операция - set_speed
        # отправка сообщения с желаемым направлением
        event_direction =  Event(source=BaseCommunicationGateway.event_source_name,
                      destination=safety_block_q_name,
                      operation="set_direction", parameters=direction
                      ) # замените на код создания сообщения с направлением для приводов
                               # подсказка, требуемая операция - set_direction
        safety_block_q.put(event_speed)
        safety_block_q.put(event_direction) 

    def _lock_cargo(self):
        """ заблокировать грузовой отсек """
        safety_q = self._queues_dir.get_queue(SAFETY_BLOCK_QUEUE_NAME)
        # инициализация сообщения с командой на блокировку грузового отсека
        # подсказка: блок CargoBay ожидает команду "lock_cargo" без параметров
        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME,
                    destination=SAFETY_BLOCK_QUEUE_NAME,
                    operation="lock_cargo", parameters= None
                    ) # <-- измените эту строку!
        safety_q.put(event)

    def _release_cargo(self):
        """ открыть грузовой отсек """
        cargo_q = self._queues_dir.get_queue(SAFETY_BLOCK_QUEUE_NAME)
        # инициализация сообщения с командой на блокировку грузового отсека
        # подсказка: блок CargoBay ожидает команду "release_cargo" без параметров
        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME,
                    destination=SAFETY_BLOCK_QUEUE_NAME,
                    operation="release_cargo", parameters= None
                    ) # <-- измените эту строку!
        cargo_q.put(event)      

class NavigationSystem(BaseNavigationSystem):
    """ класс навигационного блока """
    def _send_position_to_consumers(self):        
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME # замените на правильное название очереди
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="position_update", parameters=self._position
                      ) # замените на код создания сообщения с координатами для системы управления 
                     # подсказка, требуемая операция - position_update
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(event)
        safety_block_q_name = SAFETY_BLOCK_QUEUE_NAME
        event = Event(source=self.event_source_name,
                    destination=safety_block_q_name,
                    operation="position_update",
                    parameters=self._position)
        safety_block_q = self._queues_dir.get_queue(safety_block_q_name)
        safety_block_q.put(event)

# 3. создайте экземпляры изменённых классов и отправьте машинку по ранее предложенному маршруту
# queues_dir = QueuesDirectory()
# safety_block = SafetyBlock(queues_dir=queues_dir, log_level=LOG_INFO)
communication_gateway = CommunicationGateway(queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)
navigation_system = NavigationSystem(queues_dir=queues_dir, log_level=LOG_ERROR)
# Out:
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation

# %%
# создадим все остальные компоненты

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

safety_block = SafetyBlock(queues_dir=queues_dir, log_level=LOG_INFO)
# Out:
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь safety
# [ИНФО][SAFETY] создан ограничитель

# %%
# соберём все компоненты для запуска

# в зависимости от наличия СУПА используем разный набор компонентов - с передачей телеметрии или без

system_components = SystemComponentsContainer(
components=[
        # вариант компонентов с передачей телеметрии в СУПА
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ] if afcs_present else [
        # вариант компонентов для конфигурации без СУПА
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ])

system_components.start()

# настройте этот параметр так, чтобы проверить работу ограничителя
sleep(200)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
# Out:
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CONTROL] старт системы управления[ИНФО][CARGO] старт блока грузового отсека
#
# [ИНФО][SAFETY] старт ограничителя
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][CONTROL] установлена новая задача, начинаем следовать по маршруту, текущее время 13:36:02.607741
# [ИНФО][CARGO] заблокировать грузовой отсек
# [ИНФО][CARGO] грузовой отсек заблокирован
# [ИНФО][CONTROL] новая скорость 20 (была 0)
# [ИНФО][CONTROL] новое направление 294 (было 0)
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.4972s N, 29 49m 48.1908s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.4972s N, 29 49m 48.1908s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.4972s N, 29 49m 48.1908s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.527s N, 29 49m 48.0608s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.5643s N, 29 49m 47.8984s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.6015s N, 29 49m 47.7359s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.6388s N, 29 49m 47.5735s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.6761s N, 29 49m 47.411s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.7133s N, 29 49m 47.2486s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.7506s N, 29 49m 47.0861s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.7879s N, 29 49m 46.9236s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.8251s N, 29 49m 46.7612s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.8624s N, 29 49m 46.5987s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.8922s N, 29 49m 46.4687s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.9294s N, 29 49m 46.3063s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.9667s N, 29 49m 46.1438s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.0039s N, 29 49m 45.9813s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.0412s N, 29 49m 45.8189s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.0784s N, 29 49m 45.6564s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.1157s N, 29 49m 45.4939s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.1455s N, 29 49m 45.3639s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.1827s N, 29 49m 45.2014s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.2199s N, 29 49m 45.039s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.2572s N, 29 49m 44.8765s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.2869s N, 29 49m 44.7465s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.3242s N, 29 49m 44.584s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.3614s N, 29 49m 44.4215s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.3986s N, 29 49m 44.259s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4358s N, 29 49m 44.0965s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.473s N, 29 49m 43.934s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5102s N, 29 49m 43.7715s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5474s N, 29 49m 43.6089s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5846s N, 29 49m 43.4464s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6144s N, 29 49m 43.3164s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6516s N, 29 49m 43.1539s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6888s N, 29 49m 42.9913s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7259s N, 29 49m 42.8288s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7631s N, 29 49m 42.6662s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8002s N, 29 49m 42.5037s E
# [ОШИБКА][SAFETY] исправление: 294.39701710360094 -> 258.64938905844554
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 255 (было 294)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8374s N, 29 49m 42.3411s E
# [ИНФО][CONTROL] новое направление 252 (было 255)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8745s N, 29 49m 42.1785s E
# [ИНФО][CONTROL] новое направление 251 (было 252)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8603s N, 29 49m 42.0384s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.839s N, 29 49m 41.865s E
# [ИНФО][CONTROL] новое направление 250 (было 251)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8127s N, 29 49m 41.6944s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7845s N, 29 49m 41.5248s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7555s N, 29 49m 41.3558s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7263s N, 29 49m 41.187s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6968s N, 29 49m 41.0183s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6673s N, 29 49m 40.8496s E
# [ОШИБКА][SAFETY] исправление: 250.75784951841592 -> 283.18271373756284
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6437s N, 29 49m 40.7147s E
# [ОШИБКА][SAFETY] исправление: 250.76303947226398 -> 285.464650646458
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 288 (было 250)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6141s N, 29 49m 40.5461s E
# [ИНФО][CONTROL] новое направление 289 (было 288)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6346s N, 29 49m 40.3722s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6585s N, 29 49m 40.2001s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6873s N, 29 49m 40.031s E
# [ИНФО][CONTROL] новое направление 290 (было 289)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7171s N, 29 49m 39.8625s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7476s N, 29 49m 39.6946s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7782s N, 29 49m 39.5268s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8091s N, 29 49m 39.3591s E
# [ОШИБКА][SAFETY] исправление: 290.1824948934611 -> 205.1761617764933
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.84s N, 29 49m 39.1914s E
# [ОШИБКА][SAFETY] исправление: 290.18833373308644 -> 204.8360424941199
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 60 (была 20)
# [ИНФО][CONTROL] новое направление 204 (было 290)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8709s N, 29 49m 39.0238s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7897s N, 29 49m 38.9478s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7082s N, 29 49m 38.8728s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4632s N, 29 49m 38.6507s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.2182s N, 29 49m 38.4286s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.9731s N, 29 49m 38.2065s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.7281s N, 29 49m 37.9844s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.483s N, 29 49m 37.7623s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.238s N, 29 49m 37.5403s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.9929s N, 29 49m 37.3182s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.7479s N, 29 49m 37.0961s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.5028s N, 29 49m 36.874s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.2578s N, 29 49m 36.6519s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.0618s N, 29 49m 36.4742s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.8167s N, 29 49m 36.252s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.5717s N, 29 49m 36.0299s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.3267s N, 29 49m 35.8078s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.0816s N, 29 49m 35.5856s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.8366s N, 29 49m 35.3635s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.5916s N, 29 49m 35.1413s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.3465s N, 29 49m 34.9192s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.1015s N, 29 49m 34.697s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.8565s N, 29 49m 34.4748s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.6115s N, 29 49m 34.2526s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.3664s N, 29 49m 34.0304s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.1214s N, 29 49m 33.8082s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.8764s N, 29 49m 33.586s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.6314s N, 29 49m 33.3638s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.3864s N, 29 49m 33.1416s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.1414s N, 29 49m 32.9194s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.8964s N, 29 49m 32.6971s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.6514s N, 29 49m 32.4749s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.4064s N, 29 49m 32.2526s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.1614s N, 29 49m 32.0303s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.9654s N, 29 49m 31.8525s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.7204s N, 29 49m 31.6302s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.4754s N, 29 49m 31.4079s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.2304s N, 29 49m 31.1855s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.9854s N, 29 49m 30.9632s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.7404s N, 29 49m 30.7408s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.4954s N, 29 49m 30.5185s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.2995s N, 29 49m 30.3405s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.0545s N, 29 49m 30.1181s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.8095s N, 29 49m 29.8957s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.5646s N, 29 49m 29.6733s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.3196s N, 29 49m 29.4508s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.0747s N, 29 49m 29.2283s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.8297s N, 29 49m 29.0058s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.5848s N, 29 49m 28.7833s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.3888s N, 29 49m 28.6052s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.1439s N, 29 49m 28.3826s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.899s N, 29 49m 28.16s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.6541s N, 29 49m 27.9373s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.4092s N, 29 49m 27.7146s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.2133s N, 29 49m 27.5364s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.9684s N, 29 49m 27.3135s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.7236s N, 29 49m 27.0906s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.4787s N, 29 49m 26.8676s E
# [ОШИБКА][SAFETY] исправление: 204.72157201372417 -> 116.47392626092397
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 114 (было 204)
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.2339s N, 29 49m 26.6444s E
# [ИНФО][CONTROL] новое направление 113 (было 114)
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.9892s N, 29 49m 26.421s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.8692s N, 29 49m 26.9005s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.7568s N, 29 49m 27.3872s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.671s N, 29 49m 27.7803s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.5641s N, 29 49m 28.272s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.4574s N, 29 49m 28.7638s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.3506s N, 29 49m 29.2556s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.2439s N, 29 49m 29.7474s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.1372s N, 29 49m 30.2392s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.0305s N, 29 49m 30.731s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.9239s N, 29 49m 31.2228s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.8172s N, 29 49m 31.7146s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.7105s N, 29 49m 32.2065s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.6038s N, 29 49m 32.6983s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.4971s N, 29 49m 33.1901s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.3905s N, 29 49m 33.682s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.2838s N, 29 49m 34.1738s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.1985s N, 29 49m 34.5673s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.0918s N, 29 49m 35.0592s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.9852s N, 29 49m 35.551s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.8786s N, 29 49m 36.0429s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.7719s N, 29 49m 36.5348s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.6653s N, 29 49m 37.0266s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.5587s N, 29 49m 37.5185s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.4521s N, 29 49m 38.0104s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.3455s N, 29 49m 38.5023s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.2389s N, 29 49m 38.9942s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.1324s N, 29 49m 39.4861s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.0258s N, 29 49m 39.9781s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.9193s N, 29 49m 40.47s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.8128s N, 29 49m 40.962s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.7062s N, 29 49m 41.4539s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.5997s N, 29 49m 41.9459s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.4933s N, 29 49m 42.4379s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.3868s N, 29 49m 42.9299s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.2804s N, 29 49m 43.422s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.174s N, 29 49m 43.914s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.0677s N, 29 49m 44.4062s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 194 (было 113)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.9614s N, 29 49m 44.8983s E
# [ИНФО][CONTROL] новое направление 211 (было 194)
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.8553s N, 29 49m 45.3906s E
# [ИНФО][CONTROL] новое направление 228 (было 211)
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.7493s N, 29 49m 45.883s E
# [ИНФО][CONTROL] новое направление 239 (было 228)
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.4881s N, 29 49m 45.7526s E
# [ИНФО][CONTROL] новое направление 254 (было 239)
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.2594s N, 29 49m 45.4698s E
# [ИНФО][CONTROL] новое направление 276 (было 254)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.0797s N, 29 49m 45.0709s E
# [ОШИБКА][SAFETY] исправление: 276.99801022786403 -> 229.69403580648287
# [ИНФО][CONTROL] новое направление 338 (было 276)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.9446s N, 29 49m 44.6076s E
# [ОШИБКА][SAFETY] исправление: 338.9147804633796 -> 227.80549327869974
# [ИНФО][CONTROL] новое направление 38 (было 338)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.8704s N, 29 49m 44.0927s E
# [ОШИБКА][SAFETY] исправление: 38.000236860979896 -> 222.14576760665523
# [ИНФО][CONTROL] новое направление 40 (было 38)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.8124s N, 29 49m 43.9565s E
# [ОШИБКА][SAFETY] исправление: 40.59138464818972 -> 221.54356135364583
# [ИНФО][CONTROL] новое направление 41 (было 40)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.7521s N, 29 49m 43.8242s E
# [ОШИБКА][SAFETY] исправление: 41.90083498715734 -> 221.00076744587568
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.6855s N, 29 49m 43.7044s E
# [ОШИБКА][SAFETY] исправление: 41.93125156926874 -> 220.8955400209303
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.6183s N, 29 49m 43.586s E
# [ОШИБКА][SAFETY] исправление: 41.87277036821149 -> 220.83186630959355
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.5506s N, 29 49m 43.4689s E
# [ОШИБКА][SAFETY] исправление: 41.76395110624526 -> 220.81749755999488
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.4828s N, 29 49m 43.352s E
# [ОШИБКА][SAFETY] исправление: 41.66701649791656 -> 220.81343250449257
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.4148s N, 29 49m 43.2352s E
# [ОШИБКА][SAFETY] исправление: 41.58252989365758 -> 220.81801595113575
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.3469s N, 29 49m 43.1185s E
# [ОШИБКА][SAFETY] исправление: 41.51153436487709 -> 220.82694325652912
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.279s N, 29 49m 43.0018s E
# [ОШИБКА][SAFETY] исправление: 41.45160815632721 -> 220.84083161874
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.2111s N, 29 49m 42.8851s E
# [ОШИБКА][SAFETY] исправление: 41.400926290179996 -> 152.02271670964876
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.1431s N, 29 49m 42.7684s E
# [ОШИБКА][SAFETY] исправление: 41.35787100024271 -> 140.3813134244948
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.0752s N, 29 49m 42.6516s E
# [ОШИБКА][SAFETY] исправление: 41.32128303806269 -> 127.89418397360407
# [ИНФО][CONTROL] новое направление 37 (было 41)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.996s N, 29 49m 42.7354s E
# [ОШИБКА][SAFETY] исправление: 37.93509867006617 -> 121.4876757537557
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] новое направление 34 (было 37)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.9296s N, 29 49m 42.8547s E
# [ОШИБКА][SAFETY] исправление: 34.42904199618101 -> 183.81412721517563
# [ИНФО][CONTROL] новое направление 30 (было 34)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.8761s N, 29 49m 42.9978s E
# [ОШИБКА][SAFETY] исправление: 30.878135302234455 -> 189.68390255392802
# [ИНФО][CONTROL] новое направление 27 (было 30)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.8207s N, 29 49m 43.1173s E
# [ОШИБКА][SAFETY] исправление: 27.750419611162158 -> 195.33522205860203
# [ИНФО][CONTROL] новое направление 26 (было 27)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.7491s N, 29 49m 43.1078s E
# [ОШИБКА][SAFETY] исправление: 26.659069090077082 -> 196.6519481379294
# [ИНФО][CONTROL] новое направление 25 (было 26)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.6606s N, 29 49m 43.0777s E
# [ОШИБКА][SAFETY] исправление: 25.729096604479082 -> 197.81975432103033
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.574s N, 29 49m 43.0305s E
# [ОШИБКА][SAFETY] исправление: 25.18347660100386 -> 198.32470839248396
# [ИНФО][CONTROL] новое направление 24 (было 25)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.488s N, 29 49m 42.9793s E
# [ОШИБКА][SAFETY] исправление: 24.756724027445557 -> 198.75287751532136
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.4026s N, 29 49m 42.9247s E
# [ОШИБКА][SAFETY] исправление: 24.425433801913755 -> 223.8880489726672
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.3174s N, 29 49m 42.8686s E
# [ОШИБКА][SAFETY] исправление: 24.146929586989415 -> 224.67119825608955
# [ИНФО][CONTROL] новое направление 23 (было 24)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.2324s N, 29 49m 42.8112s E
# [ОШИБКА][SAFETY] исправление: 23.911093525962144 -> 225.48762442528698
# [ИНФО][CONTROL] новое направление 24 (было 23)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.1677s N, 29 49m 42.6874s E
# [ОШИБКА][SAFETY] исправление: 24.72746490108699 -> 225.54302769562455
# [ИНФО][CONTROL] новое направление 25 (было 24)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.1039s N, 29 49m 42.5619s E
# [ОШИБКА][SAFETY] исправление: 25.511607675889024 -> 225.5750342701426
# [ИНФО][CONTROL] новое направление 26 (было 25)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.0409s N, 29 49m 42.4345s E
# [ОШИБКА][SAFETY] исправление: 26.268272284380373 -> 225.57990755831395
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.9781s N, 29 49m 42.3071s E
# [ОШИБКА][SAFETY] исправление: 26.973473232449635 -> 225.58307377097745
# [ИНФО][CONTROL] новое направление 27 (было 26)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.9152s N, 29 49m 42.1796s E
# [ОШИБКА][SAFETY] исправление: 27.63153410655815 -> 225.58520537071416
# [ИНФО][CONTROL] новое направление 28 (было 27)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.8524s N, 29 49m 42.0521s E
# [ОШИБКА][SAFETY] исправление: 28.24604168472922 -> 225.5873273361989
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.7896s N, 29 49m 41.9245s E
# [ОШИБКА][SAFETY] исправление: 28.821017453419017 -> 225.58950472935373
# [ИНФО][CONTROL] новое направление 29 (было 28)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.7268s N, 29 49m 41.797s E
# [ОШИБКА][SAFETY] исправление: 29.360035128778463 -> 225.59178136657437
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.664s N, 29 49m 41.6695s E
# [ОШИБКА][SAFETY] исправление: 29.86628493735168 -> 225.59417079093933
# [ИНФО][CONTROL] новое направление 30 (было 29)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.6012s N, 29 49m 41.5419s E
# [ОШИБКА][SAFETY] исправление: 30.342602311659448 -> 225.59668623085747
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.5384s N, 29 49m 41.4144s E
# [ОШИБКА][SAFETY] исправление: 30.79151405555092 -> 225.5993416821568
# [ИНФО][CONTROL] новое направление 31 (было 30)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.4881s N, 29 49m 41.3123s E
# [ОШИБКА][SAFETY] исправление: 31.13243078288974 -> 225.6015884276929
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.4253s N, 29 49m 41.1848s E
# [ОШИБКА][SAFETY] исправление: 31.537541795657717 -> 225.60454004846952
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.3625s N, 29 49m 41.0572s E
# [ОШИБКА][SAFETY] исправление: 31.920994862096165 -> 225.60768532253803
# [ИНФО][CONTROL] новое направление 32 (было 31)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.2997s N, 29 49m 40.9296s E
# [ОШИБКА][SAFETY] исправление: 32.28444479965049 -> 225.61108637858422
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.2369s N, 29 49m 40.8021s E
# [ОШИБКА][SAFETY] исправление: 32.62941251973331 -> 225.6147474002548
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.1741s N, 29 49m 40.6745s E
# [ОШИБКА][SAFETY] исправление: 32.95726018927371 -> 225.61871047369314
# [ИНФО][CONTROL] новое направление 33 (было 32)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.1113s N, 29 49m 40.5469s E
# [ОШИБКА][SAFETY] исправление: 33.26922346668749 -> 225.62302590094177
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.0485s N, 29 49m 40.4193s E
# [ОШИБКА][SAFETY] исправление: 33.56642439523171 -> 225.62776049979715
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.9858s N, 29 49m 40.2917s E
# [ОШИБКА][SAFETY] исправление: 33.84988484922815 -> 225.63300169720654
# [ИНФО][CONTROL] новое направление 34 (было 33)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.923s N, 29 49m 40.1641s E
# [ОШИБКА][SAFETY] исправление: 34.1205375920444 -> 225.63886706241433
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.8602s N, 29 49m 40.0365s E
# [ОШИБКА][SAFETY] исправление: 34.37923612523707 -> 225.64551936056108
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.7975s N, 29 49m 39.9088s E
# [ОШИБКА][SAFETY] исправление: 34.62678901688065 -> 225.65304448081363
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.7347s N, 29 49m 39.7812s E
# [ОШИБКА][SAFETY] исправление: 34.8638932844882 -> 225.66187682633978
# [ИНФО][CONTROL] новое направление 35 (было 34)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.672s N, 29 49m 39.6535s E
# [ОШИБКА][SAFETY] исправление: 35.0912140453878 -> 225.67254218082596
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.6092s N, 29 49m 39.5258s E
# [ОШИБКА][SAFETY] исправление: 35.309366313175985 -> 225.68596145319225
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.5465s N, 29 49m 39.3981s E
# [ОШИБКА][SAFETY] исправление: 35.51892584001746 -> 225.70387782812148
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.4838s N, 29 49m 39.2704s E
# [ОШИБКА][SAFETY] исправление: 35.72043585683218 -> 169.84375472239537
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.4211s N, 29 49m 39.1426s E
# [ОШИБКА][SAFETY] исправление: 35.91441941976859 -> 166.98518536369693
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.3532s N, 29 49m 39.0467s E
# [ОШИБКА][SAFETY] исправление: 35.904706279839615 -> 164.49876015592463
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.2651s N, 29 49m 39.0799s E
# [ОШИБКА][SAFETY] исправление: 35.11103196553529 -> 164.17924413893388
# [ИНФО][CONTROL] новое направление 34 (было 35)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.1951s N, 29 49m 39.1121s E
# [ОШИБКА][SAFETY] исправление: 34.467199525029514 -> 164.0197620956401
# [ИНФО][CONTROL] новое направление 33 (было 34)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.1086s N, 29 49m 39.1598s E
# [ОШИБКА][SAFETY] исправление: 33.64968709076595 -> 163.98152319176086
# [ИНФО][CONTROL] новое направление 32 (было 33)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.0223s N, 29 49m 39.2085s E
# [ОШИБКА][SAFETY] исправление: 32.84798677057995 -> 163.9632052196646
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.936s N, 29 49m 39.2576s E
# [ОШИБКА][SAFETY] исправление: 32.06362121913719 -> 163.95585736632893
# [ИНФО][CONTROL] новое направление 31 (было 32)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.8497s N, 29 49m 39.3069s E
# [ОШИБКА][SAFETY] исправление: 31.297649494399877 -> 163.95081649386623
# [ИНФО][CONTROL] новое направление 30 (было 31)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.7634s N, 29 49m 39.3562s E
# [ОШИБКА][SAFETY] исправление: 30.549903571873188 -> 163.94666902289805
# [ИНФО][CONTROL] новое направление 29 (было 30)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.6772s N, 29 49m 39.4056s E
# [ОШИБКА][SAFETY] исправление: 29.820103384687002 -> 163.94240298243608
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.5909s N, 29 49m 39.4549s E
# [ОШИБКА][SAFETY] исправление: 29.107860558030836 -> 163.9376477888154
# [ИНФО][CONTROL] новое направление 28 (было 29)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.5047s N, 29 49m 39.5043s E
# [ОШИБКА][SAFETY] исправление: 28.41276786387573 -> 163.93202141321876
# [ИНФО][CONTROL] новое направление 27 (было 28)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.4184s N, 29 49m 39.5537s E
# [ОШИБКА][SAFETY] исправление: 27.73440561527792 -> 163.92504182781386
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.3321s N, 29 49m 39.6031s E
# [ОШИБКА][SAFETY] исправление: 27.072350916087487 -> 163.91585394041215
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] новое направление 26 (было 27)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.2459s N, 29 49m 39.6525s E
# [ОШИБКА][SAFETY] исправление: 26.426178822258237 -> 202.5857533689702
# [ИНФО][CONTROL] новое направление 25 (было 26)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.1596s N, 29 49m 39.7019s E
# [ОШИБКА][SAFETY] исправление: 25.795462307255946 -> 207.65213069348917
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.0734s N, 29 49m 39.7514s E
# [ОШИБКА][SAFETY] исправление: 25.179768824782855 -> 213.86537979042495
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.9905s N, 29 49m 39.6828s E
# [ОШИБКА][SAFETY] исправление: 25.138110502824986 -> 215.9441560427227
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.911s N, 29 49m 39.6s E
# [ОШИБКА][SAFETY] исправление: 25.17667327491182 -> 217.82202203559027
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.8365s N, 29 49m 39.5005s E
# [ОШИБКА][SAFETY] исправление: 25.308915469451506 -> 158.6493222089416
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.7638s N, 29 49m 39.3957s E
# [ОШИБКА][SAFETY] исправление: 25.46820026141694 -> 153.57466496165614
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.6929s N, 29 49m 39.2862s E
# [ОШИБКА][SAFETY] исправление: 25.650253553378207 -> 147.9079470263868
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.6093s N, 29 49m 39.3512s E
# [ОШИБКА][SAFETY] исправление: 25.03189807780359 -> 146.5910384855332
# [ИНФО][CONTROL] новое направление 24 (было 25)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5289s N, 29 49m 39.4307s E
# [ОШИБКА][SAFETY] исправление: 24.37676096313021 -> 145.61042415756708
# [ИНФО][CONTROL] новое направление 23 (было 24)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4531s N, 29 49m 39.5262s E
# [ОШИБКА][SAFETY] исправление: 23.682156476284263 -> 145.2723802123665
# [ИНФО][CONTROL] новое направление 22 (было 23)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3784s N, 29 49m 39.625s E
# [ОШИБКА][SAFETY] исправление: 22.988675209251767 -> 145.04557656799386
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3191s N, 29 49m 39.7057s E
# [ОШИБКА][SAFETY] исправление: 22.43678701237019 -> 144.93328729943642
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] новое направление 21 (было 22)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.2453s N, 29 49m 39.8074s E
# [ОШИБКА][SAFETY] исправление: 21.75393644731065 -> 83.63105878111867
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1718s N, 29 49m 39.9097s E
# [ОШИБКА][SAFETY] исправление: 21.07993099291656 -> 81.44224421014655
# [ИНФО][CONTROL] новое направление 20 (было 21)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.0983s N, 29 49m 40.0123s E
# [ОШИБКА][SAFETY] исправление: 20.415570406783843 -> 79.16941709640253
# [ИНФО][CONTROL] новое направление 19 (было 20)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1083s N, 29 49m 40.1897s E
# [ОШИБКА][SAFETY] исправление: 19.697451431648176 -> 78.96362215326064
# [ИНФО][CONTROL] новое направление 18 (было 19)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1216s N, 29 49m 40.3663s E
# [ОШИБКА][SAFETY] исправление: 18.98420102122884 -> 78.84408873800959
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1385s N, 29 49m 40.5416s E
# [ОШИБКА][SAFETY] исправление: 18.27674290740356 -> 78.82845071931627
# [ИНФО][CONTROL] новое направление 17 (было 18)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1557s N, 29 49m 40.7169s E
# [ОШИБКА][SAFETY] исправление: 17.560822992708893 -> 78.82220955266655
# [ИНФО][CONTROL] новое направление 16 (было 17)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.173s N, 29 49m 40.892s E
# [ОШИБКА][SAFETY] исправление: 16.83583701095239 -> 78.82223643471428
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.187s N, 29 49m 41.0321s E
# [ОШИБКА][SAFETY] исправление: 16.24878938298309 -> 78.82285504647479
# [ИНФО][CONTROL] новое направление 15 (было 16)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.2044s N, 29 49m 41.2073s E
# [ОШИБКА][SAFETY] исправление: 15.506145584994954 -> 78.82410958042999
# [ИНФО][CONTROL] новое направление 14 (было 15)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.2218s N, 29 49m 41.3824s E
# [ОШИБКА][SAFETY] исправление: 14.753689797581046 -> 78.82552896875552
# [ИНФО][CONTROL] новое направление 13 (было 14)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.2392s N, 29 49m 41.5576s E
# [ОШИБКА][SAFETY] исправление: 13.991487273893938 -> 78.82710609333242
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.2565s N, 29 49m 41.7327s E
# [ОШИБКА][SAFETY] исправление: 13.219618923315352 -> 78.8288281790376
# [ИНФО][CONTROL] новое направление 12 (было 13)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.2739s N, 29 49m 41.9079s E
# [ОШИБКА][SAFETY] исправление: 12.438185061274282 -> 78.83071807023288
# [ИНФО][CONTROL] новое направление 11 (было 12)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.2913s N, 29 49m 42.0831s E
# [ОШИБКА][SAFETY] исправление: 11.647302923195241 -> 78.83280775279871
# [ИНФО][CONTROL] новое направление 10 (было 11)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3087s N, 29 49m 42.2582s E
# [ОШИБКА][SAFETY] исправление: 10.847105063260017 -> 78.83510493881613
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3226s N, 29 49m 42.3983s E
# [ОШИБКА][SAFETY] исправление: 10.200343714494466 -> 78.83717222229552
# [ИНФО][CONTROL] новое направление 9 (было 10)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.34s N, 29 49m 42.5735s E
# [ОШИБКА][SAFETY] исправление: 9.383777628999553 -> 78.84007133443293
# [ИНФО][CONTROL] новое направление 8 (было 9)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3574s N, 29 49m 42.7487s E
# [ОШИБКА][SAFETY] исправление: 8.55837075295966 -> 78.8434639310189
# [ИНФО][CONTROL] новое направление 7 (было 8)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3748s N, 29 49m 42.9238s E
# [ОШИБКА][SAFETY] исправление: 7.724329653450695 -> 78.84763506240245
# [ИНФО][CONTROL] новое направление 6 (было 7)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3921s N, 29 49m 43.099s E
# [ОШИБКА][SAFETY] исправление: 6.8818745922155244 -> 78.8528851292092
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.406s N, 29 49m 43.2391s E
# [ОШИБКА][SAFETY] исправление: 6.202012812315843 -> 78.85823026919695
# [ИНФО][CONTROL] новое направление 5 (было 6)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4234s N, 29 49m 43.4143s E
# [ОШИБКА][SAFETY] исправление: 5.3450297712767 -> 124.82969205421301
# [ИНФО][CONTROL] новое направление 4 (было 5)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4408s N, 29 49m 43.5895s E
# [ОШИБКА][SAFETY] исправление: 4.480354972910561 -> 126.21547080256033
# [ИНФО][CONTROL] новое направление 3 (было 4)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4581s N, 29 49m 43.7646s E
# [ОШИБКА][SAFETY] исправление: 3.6082870302638526 -> 127.66566675179604
# [ИНФО][CONTROL] новое направление 2 (было 3)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4068s N, 29 49m 43.9112s E
# [ОШИБКА][SAFETY] исправление: 2.8402161761017055 -> 127.76510006523341
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3538s N, 29 49m 44.0552s E
# [ОШИБКА][SAFETY] исправление: 2.0966819255430096 -> 127.8206801989985
# [ИНФО][CONTROL] новое направление 1 (было 2)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.299s N, 29 49m 44.1966s E
# [ОШИБКА][SAFETY] исправление: 1.3790083781829594 -> 127.82485874832219
# [ИНФО][CONTROL] новое направление 0 (было 1)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.255s N, 29 49m 44.3095s E
# [ОШИБКА][SAFETY] исправление: 0.8149547604421628 -> 127.82528835853412
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1999s N, 29 49m 44.4505s E
# [ОШИБКА][SAFETY] исправление: 0.12198904672663957 -> 127.82357195293815
# [ИНФО][CONTROL] новое направление 359 (было 0)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1449s N, 29 49m 44.5915s E
# [ОШИБКА][SAFETY] исправление: 359.44180075037565 -> 127.8215267796316
# [ИНФО][CONTROL] новое направление 358 (было 359)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.0899s N, 29 49m 44.7326s E
# [ОШИБКА][SAFETY] исправление: 358.7741938734776 -> 127.81927702247464
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.0348s N, 29 49m 44.8736s E
# [ОШИБКА][SAFETY] исправление: 358.1189789591166 -> 127.81689479660588
# [ИНФО][CONTROL] новое направление 357 (было 358)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.9798s N, 29 49m 45.0146s E
# [ОШИБКА][SAFETY] исправление: 357.47597663390127 -> 127.81437672154112
# [ИНФО][CONTROL] новое направление 356 (было 357)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.9357s N, 29 49m 45.1274s E
# [ОШИБКА][SAFETY] исправление: 356.9702425653875 -> 127.81226719927992
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.8807s N, 29 49m 45.2685s E
# [ОШИБКА][SAFETY] исправление: 356.34875629168437 -> 127.80947481242043
# [ИНФО][CONTROL] новое направление 355 (было 356)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.8257s N, 29 49m 45.4095s E
# [ОШИБКА][SAFETY] исправление: 355.73895203630786 -> 127.8065322031066
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.7706s N, 29 49m 45.5506s E
# [ОШИБКА][SAFETY] исправление: 355.1406444816665 -> 127.8033581983745
# [ИНФО][CONTROL] новое направление 354 (было 355)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.7156s N, 29 49m 45.6916s E
# [ОШИБКА][SAFETY] исправление: 354.55363065616837 -> 127.79995208935082
# [ИНФО][CONTROL] новое направление 353 (было 354)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.6606s N, 29 49m 45.8327s E
# [ОШИБКА][SAFETY] исправление: 353.97771055972794 -> 127.7962761144787
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.6056s N, 29 49m 45.9738s E
# [ОШИБКА][SAFETY] исправление: 353.412681937101 -> 127.79228732462605
# [ИНФО][CONTROL] новое направление 352 (было 353)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.5506s N, 29 49m 46.1148s E
# [ОШИБКА][SAFETY] исправление: 352.85834160480834 -> 127.78792903764435
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.4956s N, 29 49m 46.2559s E
# [ОШИБКА][SAFETY] исправление: 352.31448561004316 -> 127.78312808940711
# [ИНФО][CONTROL] новое направление 351 (было 352)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.4406s N, 29 49m 46.397s E
# [ОШИБКА][SAFETY] исправление: 351.7809013172172 -> 127.77787080516038
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.3966s N, 29 49m 46.5099s E
# [ОШИБКА][SAFETY] исправление: 351.36130132515245 -> 127.77316762612088
# [ИНФО][CONTROL] новое направление 350 (было 351)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.3416s N, 29 49m 46.651s E
# [ОШИБКА][SAFETY] исправление: 350.84570503572627 -> 127.76661778931992
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.2866s N, 29 49m 46.7921s E
# [ОШИБКА][SAFETY] исправление: 350.33981683079594 -> 127.75904002514403
# [ИНФО][CONTROL] новое направление 349 (было 350)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.2316s N, 29 49m 46.9332s E
# [ОШИБКА][SAFETY] исправление: 349.8434444712029 -> 127.74988806449369
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.1766s N, 29 49m 47.0743s E
# [ОШИБКА][SAFETY] исправление: 349.3563746253054 -> 127.7386539398342
# [ИНФО][CONTROL] новое направление 348 (было 349)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.1217s N, 29 49m 47.2155s E
# [ОШИБКА][SAFETY] исправление: 348.87840385144665 -> 127.72421790788962
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.0667s N, 29 49m 47.3567s E
# [ОШИБКА][SAFETY] исправление: 348.4093258632643 -> 127.70438581286919
# [ИНФО][CONTROL] новое направление 347 (было 348)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.0118s N, 29 49m 47.4979s E
# [ОШИБКА][SAFETY] исправление: 347.9489321704575 -> 179.25596881970864
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.9569s N, 29 49m 47.6391s E
# [ОШИБКА][SAFETY] исправление: 347.4970065942747 -> 181.6454472776246
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.902s N, 29 49m 47.7803s E
# [ОШИБКА][SAFETY] исправление: 347.0533155516051 -> 184.19032426541287
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.8122s N, 29 49m 47.7826s E
# [ОШИБКА][SAFETY] исправление: 347.19845416836887 -> 184.4771016111752
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.7225s N, 29 49m 47.7775s E
# [ОШИБКА][SAFETY] исправление: 347.367747048352 -> 184.65218925495887
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.633s N, 29 49m 47.7645s E
# [ОШИБКА][SAFETY] исправление: 347.5618830134407 -> 184.68307334505405
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.5435s N, 29 49m 47.7505s E
# [ОШИБКА][SAFETY] исправление: 347.7548875344422 -> 184.6981259798054
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.454s N, 29 49m 47.7361s E
# [ОШИБКА][SAFETY] исправление: 347.94557541564694 -> 184.70220264403866
# [ИНФО][CONTROL] новое направление 348 (было 347)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.3646s N, 29 49m 47.7215s E
# [ОШИБКА][SAFETY] исправление: 348.13245890439185 -> 184.70441791226767
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.2751s N, 29 49m 47.7069s E
# [ОШИБКА][SAFETY] исправление: 348.3154876354303 -> 184.70568582320112
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.1856s N, 29 49m 47.6922s E
# [ОШИБКА][SAFETY] исправление: 348.4946646863865 -> 184.7068034194723
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.0962s N, 29 49m 47.6776s E
# [ОШИБКА][SAFETY] исправление: 348.67008883489615 -> 184.70792397214012
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.0067s N, 29 49m 47.6629s E
# [ОШИБКА][SAFETY] исправление: 348.84186447729616 -> 184.7091641530255
# [ИНФО][CONTROL] новое направление 349 (было 348)
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.9173s N, 29 49m 47.6483s E
# [ОШИБКА][SAFETY] исправление: 349.0101001553722 -> 184.71059482793902
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.8278s N, 29 49m 47.6336s E
# [ОШИБКА][SAFETY] исправление: 349.17490177407393 -> 184.7123079591805
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.7384s N, 29 49m 47.619s E
# [ОШИБКА][SAFETY] исправление: 349.3363723524569 -> 184.7144440124895
# [ИНФО][SAFETY] Скорость 60 превышает лимит 20. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.6489s N, 29 49m 47.6043s E
# [ОШИБКА][SAFETY] исправление: 349.4946116973397 -> 184.71726089227053
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.5595s N, 29 49m 47.5896s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.47s N, 29 49m 47.575s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] Скорость 60 превышает лимит 0.0. Ограничиваем.
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.3805s N, 29 49m 47.5603s E

# %% [markdown]
# #### Обеспечение ЦБ3: контроль доставки груза
#
# С помощью логики ограничителя выше мы реализовали обеспечение ЦБ1 (соблюдение заданных ограничений), однако есть ещё ЦБ3 (отгрузка только в заданной точке), не говоря о ЦБ2 (следование только по аутентичному маршруту).
#
# Для обеспечения ЦБ3 необходимо сделать следующее
# 1. изменить последовательность передачи команд, чтобы в блок управления грузовым отсеком (CargoBay) команды приходили только после проверки в Ограничителе
# 2. доработайте реализацию Ограничителя, чтобы команда на выгрузку передавалась в CargoBay только в конечной точке маршрута
# 3. продумайте логику работы блока безопасности, если система управления полностью перестанет работать (т.е. перестанет отправлять новые команды).
#
# Изменённая архитектура приведена на рис. 7.
#
# ![Ограничитель для обеспечения ЦБ1 и ЦБ3](images/ciac-arch-m312.png)
#
# Рис. 7. Ограничитель для обеспечения ЦБ1 и ЦБ3

# %%
# напишите свой код в этой ячейке, запустите машинку по маршруту, убедитесь, 
# что в конечной (и только в конечной!) точке CargoBay получает команду и успешно выполняет выгрузку

# %% [markdown]
# #### *Опциональное задание повышенной сложности* Обеспечение ЦБ2
#
# **Перед началом работы над этой задачей рекомендуем сохранить все текущие изменения в git репозитории (git commit, git push).**
#
# Напомним цель безопасности №2 (ЦБ2): "При любых обстоятельствах АНТС выполняет только аутентичный (подлинный) маршрут"
#
# Обеспечение ЦБ2 потребует
# - внедрения механизма **контроля аутентичности маршрутного задания** (mission), а значит
# - помимо изменения **блока безопасности** (SafetyBlock), модификации
#   - системы **планирования задания** (MissionPlanner)
#   - **коммуникационного шлюза** (CommunicationGateway)
#   - и, возможно, **системы управления** (ControlSystem).
#
# Для решения этой задачи допустимо менять код соответствующих модулей в папке src.
#
# Возможным решением является внедрение механизма цифровой подписи, верификацией которой будет заниматься блок безопасности. В этой ситуации если коммуникационный шлюз (блок "1. Связь" на рис. 5 в модуле 1) оказался скомпрометированным и изменил маршрутное задание, оно не должно пройти проверку подлинности в блоке безопасности.
#
# **Рекомендуем эту задачу делать в последнюю очередь**, *после успешного выполнения модуля 4*, поскольку успешное выполнение модуля 4 принесёт больше баллов, чем внедрение цифровой подписи и обеспечение ЦБ2.
# К сведению, реализованные в этой версии киберпрепятствия не предполагают компрометацию маршрутного задания.
#
# Конечно, если будут решены все основные задачи и к тому же обеспечен контроль аутентичности маршрутного задания, такая работа с высокой вероятностью окажется лучшей.

# %%
# если вы собираетесь выполнить это задание, напишите в этой ячейке код выполнения изменённых блоков. 
# cам код допускается редактировать в папке src
# в случае успешной реализации машинка должна успешно пройти по маршруту, а в случае искажения маршрутного задания в блоке коммуникационного шлюза должна остаться на месте, 
# при этом именно блок безопасности должен заблокировать движение

# %% [markdown]
# ### Задание 3.2. Монитор безопасности

# %% [markdown]
# В текущей реализации каждый блок сам решает куда и какие данные ему отправлять. Это приемлемо, когда каждый блок рассматривается как благонадёжный. Однако нельзя исключать ситуацию успешной компрометации какого-либо из блоков (одного или нескольких), в результате которой злоумышленник может получить полный контроль над частью системы.
#
# В такой ситуации необходимо выстроить внутреннюю "поверхность защиты", частью этой системы уже является блок "Ограничитель", однако необходимо сделать так, чтобы соответствующие запросы проходили только через него, а не в обход.
#
# Для решения этой задачи необходимо добавить новый блок "Монитор безопасности". Его задача - обеспечить контроль направления информационных потоков, допустить передачу данных только между теми блоками и в тех направлениях, которые задуманы архитектором системы. Тогда, например, попытка передать команду из системы управления напрямую в сервоприводы в обход ограничителя будет заблокирована.
#
# Возможно, возникнет вопрос, а что помешает злоумышленнику отправить команду в обход этого монитора безопасности. В рамках этой учебной инфраструктуры особо ничего, однако при разработке реальной системы можно использовать специализированные микроядерные операционные системы, такие как, например, KasperskyOS, которые обеспечат обязательное вовлечение монитора безопасности в контроль взаимодействия между блоками.
#
# Архитектура системы для решения задачи 3.2 должна выглядеть как на рис.8:
#
# ![Архитектура системы с монитором безопасности](images/ciac-arch-m32.png)
#
# Рис. 8. Архитектура бортовых систем с монитором безопасности

# %% [markdown]
# Базовый класс модуля безопасности находится в файле src/security_monitor.py, его менять не нужно.
#
# В следующей ячейке находится реализация класса SecurityMonitor

# %%
from src.security_monitory import BaseSecurityMonitor
from src.security_policy_type import SecurityPolicy

from src.config import COMMUNICATION_GATEWAY_QUEUE_NAME, LOG_DEBUG, LOG_ERROR, LOG_INFO
    
    
class SecurityMonitor(BaseSecurityMonitor):
    """ класс монитора безопасности """

    def __init__(self, queues_dir):
        super().__init__(queues_dir)
        self._init_set_security_policies()

    def _init_set_security_policies(self):
        """ инициализация политик безопасности """
        default_policies = [
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='set_mission')
        ]
        self.set_security_policies(policies=default_policies)        

    def set_security_policies(self, policies):
        """ установка новых политик безопасности """
        self._security_policies = policies
        self._log_message(
            LOG_INFO, f"изменение политик безопасности: {policies}")

    def _check_event(self, event: Event):
        """ проверка входящих событий """
        self._log_message(
            LOG_DEBUG, f"проверка события {event}, по умолчанию выполнение запрещено")

        authorized = False
        request = SecurityPolicy(
            source=event.source,
            destination=event.destination,
            operation=event.operation)

        if request in self._security_policies:
            self._log_message(
                LOG_DEBUG, "событие разрешено политиками, выполняем")
            authorized = True

        if authorized is False:
            self._log_message(LOG_ERROR, f"событие не разрешено политиками безопасности! {event}")
        return authorized

# %% [markdown]
# Обратите внимание на этот код:
# ```python
#     def _init_set_security_policies(self):
#         """ инициализация политик безопасности """
#         default_policies = [
#             SecurityPolicy(
#                 source=COMMUNICATION_GATEWAY_QUEUE_NAME,
#                 destination=CONTROL_SYSTEM_QUEUE_NAME,
#                 operation='set_mission')
#         ]
#         self.set_security_policies(policies=default_policies)
# ```
#
# В нём инициализируется политика безопасности, разрешающая запрос set_mission от коммуникационного шлюза в систему управления.
#
# Код политики безопасности в строка 6-9:
# ```python
# SecurityPolicy(
#                 source=COMMUNICATION_GATEWAY_QUEUE_NAME,
#                 destination=CONTROL_SYSTEM_QUEUE_NAME,
#                 operation='set_mission')
# ```
#
# Шаблон политики безопасности описан в файле src/security_policy_type.py:
# ```python
# @dataclass
# class SecurityPolicy:
#     """ политика безопасности """
#     source: str         # отправитель запроса
#     destination: str    # получатель
#     operation: str      # запрашиваемая операция
#
# ```
#
# По аналогии в методе _init_set_security_policies допишите другие политики безопасности, чтобы разрешить взаимодействия согласно диаграмме на рис.7. выше.

# %% [markdown]
# Теперь необходимо изменить взаимодействие между блоками так, чтобы оно всегда проходило через монитор безопасности. Для этого потребуется изменить соответствующие реализации внутренних блоков.

# %% [markdown]
# Ниже пример для блока навигации. Обратите внимание на выделенные строки и комментарии.
#
# ```python
# from src.navigation_system import BaseNavigationSystem
# from src.config import CONTROL_SYSTEM_QUEUE_NAME, SECURITY_MONITOR_QUEUE_NAME
#
#
# class NavigationSystem(BaseNavigationSystem):
#     """ класс навигационного блока """
#     def _send_position_to_consumers(self):
#         # событие для системы управления,
#         # поэтому в destination указываем CONTROL_SYSTEM_QUEUE_NAME
#         event = Event(source=self.event_source_name,
# >>>                      destination=CONTROL_SYSTEM_QUEUE_NAME,
#                       operation="position_update", parameters=self._position
#                       )
#         # но событие отправляем сначала на проверку в монитор безопасности,
#         # поэтому используем очередь с именем SECURITY_MONITOR_QUEUE_NAME
# >>>        security_monitor_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
#         security_monitor_q.put(event)
#         # а в систему управления наше событие монитор безопасности отправит сам, если найдёт разрешающую эту операцию политику безопасности
#
# navigation_system = NavigationSystem(queues_dir=queues_dir)
# ```

# %% [markdown]
# from src.navigation_system import BaseNavigationSystem
# from src.config import CONTROL_SYSTEM_QUEUE_NAME, SECURITY_MONITOR_QUEUE_NAME
#
#
# class NavigationSystem(BaseNavigationSystem):
#     """ класс навигационного блока """
#     def _send_position_to_consumers(self):
#         event = Event(source=self.event_source_name,
#                       destination=CONTROL_SYSTEM_QUEUE_NAME,
#                       operation="position_update", parameters=self._position
#                       )
#         security_monitor_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
#         security_monitor_q.put(event)
#
# navigation_system = NavigationSystem(queues_dir=queues_dir)

# %% [markdown]
# В файле tests/module/test_security_monitor.py можно увидеть тест логики работы монитора безопасности. Запустить его можно следующей командой:

# %%
# !pytest -svk security_monitor
# Out:
# /bin/bash: line 1: /home/hk/prog/cyberimmune/jupyter_env/bin/pytest: cannot execute: required file not found

# %% [markdown]
# В одном кодовом блоке ниже (или нескольких - как будет удобнее)  сделайте следующее
#
# 1. Измените реализацию монитора безопасности в части правил проверки передаваемых сообщений в мониторе безопасности
# 2. Измените параметры отправки сообщений между элементами бортовых систем (блоками 1-7), чтобы они всегда отправлялись в очередь монитора безопасности (отправитель и получатель при этом не меняются)
# 3. После всех изменений убедитесь в том, что машинка по-прежнему успешно выполняет маршрутное задание и доставляет груз
# 4. Дополнительные баллы принесут автоматические тесты правил безопасности в файле tests/module/test_security_monitor.py - можно проверить, что все новые политики работают как ожидаются, а недопустимые взаимодействия (т.е. таких стрелок нет на рис. 8) блокируются

# %%
# # добавьте изменения сюда
# from src.security_monitory import BaseSecurityMonitor
# from src.security_policy_type import SecurityPolicy

# class SecurityMonitor(BaseSecurityMonitor):
#     def _init_set_security_policies(self):
#         policies = [
#             SecurityPolicy(source=COMMUNICATION_GATEWAY_QUEUE_NAME, destination=SAFETY_BLOCK_QUEUE_NAME, operation="set_mission"),
#             SecurityPolicy(source=CONTROL_SYSTEM_QUEUE_NAME, destination=SAFETY_BLOCK_QUEUE_NAME, operation="set_speed"),
#             SecurityPolicy(source=CONTROL_SYSTEM_QUEUE_NAME, destination=SAFETY_BLOCK_QUEUE_NAME, operation="set_direction"),
#             SecurityPolicy(source=NAVIGATION_QUEUE_NAME, destination=SAFETY_BLOCK_QUEUE_NAME, operation="position_update"),
#             SecurityPolicy(source=SAFETY_BLOCK_QUEUE_NAME, destination=SERVOS_QUEUE_NAME, operation="set_speed"),
#             SecurityPolicy(source=SAFETY_BLOCK_QUEUE_NAME, destination=SERVOS_QUEUE_NAME, operation="set_direction"),
#             SecurityPolicy(source=SAFETY_BLOCK_QUEUE_NAME, destination=CARGO_BAY_QUEUE_NAME, operation="release"),
#             SecurityPolicy(source=NAVIGATION_QUEUE_NAME, destination=CONTROL_SYSTEM_QUEUE_NAME, operation="position_update")
#         ]
#         self.set_security_policies(policies)

# class CommunicationGateway(BaseCommunicationGateway):
#     def _send_mission_to_consumers(self):
#         event = Event(source=self.event_source_name, destination=SAFETY_BLOCK_QUEUE_NAME, operation="set_mission", parameters=self._mission)
#         security_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
#         security_q.put(event)

# class ControlSystem(BaseControlSystem):
#     """ControlSystem блок расчёта управления """
#     def _send_speed_and_direction_to_consumers(self, speed, direction):
#         security_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
#         event_speed = Event(source=self.event_source_name, destination=SAFETY_BLOCK_QUEUE_NAME, operation="set_speed", parameters=speed)
#         event_direction = Event(source=self.event_source_name, destination=SAFETY_BLOCK_QUEUE_NAME, operation="set_direction", parameters=direction)
#         security_q.put(event_speed)
#         security_q.put(event_direction)

# class NavigationSystem(BaseNavigationSystem):
#     def _send_position_to_consumers(self):
#         for dest in [CONTROL_SYSTEM_QUEUE_NAME, SAFETY_BLOCK_QUEUE_NAME]:
#             event = Event(source=self.event_source_name, destination=dest, operation="position_update", parameters=self._position)
#             security_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
#             security_q.put(event)

# class SafetyBlock(BaseSafetyBlock):
#     def _send_speed_to_consumers(self):
#         event = Event(source=self.event_source_name, destination=SERVOS_QUEUE_NAME, operation="set_speed", parameters=self._speed)
#         security_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
#         security_q.put(event)

# queues_dir = QueuesDirectory()
# security_monitor = SecurityMonitor(queues_dir)
# communication_gateway = CommunicationGateway(queues_dir=queues_dir, log_level=LOG_ERROR)
# control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)
# navigation_system = NavigationSystem(queues_dir=queues_dir, log_level=LOG_ERROR)

# if afcs_present:
#     mission_sender = MissionSender(
#         queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
#     telemetry_sender = TelemetrySender(
#         queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
# mission_planner = MissionPlanner(
#     queues_dir, afcs_present=afcs_present, mission=mission)
# sitl = SITL(
#     queues_dir=queues_dir, position=home,
#     car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

# servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
# cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)
# safety_block = SafetyBlock(queues_dir=queues_dir, log_level=LOG_INFO)

# system_components = SystemComponentsContainer(
# components=[
#         # вариант компонентов с передачей телеметрии в СУПА
#         mission_sender,
#         telemetry_sender,
#         sitl,
#         mission_planner,
#         navigation_system,
#         servos,
#         cargo_bay,
#         communication_gateway,
#         control_system,
#         safety_block,
#         security_monitor
#     ] if afcs_present else [
#         # вариант компонентов для конфигурации без СУПА
#         sitl,
#         mission_planner,
#         navigation_system,
#         servos,
#         cargo_bay,
#         communication_gateway,
#         control_system,
#         safety_block
#     ])


# system_components.start()

# sleep(200)

# system_components.stop()

# # def test_security_policies():
# #     queues_dir = QueuesDirectory()
# #     monitor = SecurityMonitor(queues_dir)
    
# #     # Разрешённое взаимодействие
# #     allowed_event = Event(source=CONTROL_SYSTEM_QUEUE_NAME, destination=SAFETY_QUEUE_NAME, operation="set_speed")
# #     assert monitor._check_event(allowed_event) == True
    
# #     # Запрещённое взаимодействие
# #     forbidden_event = Event(source=CONTROL_SYSTEM_QUEUE_NAME, destination=SERVOS_QUEUE_NAME, operation="set_speed")
# #     assert monitor._check_event(forbidden_event) == False

# %% [markdown]
# На этом модуль 3 завершён!
#
# Если у вас всё получилось, то вы создали защищённую автономную машинку - ещё уже не так-то просто использовать для нанесения критического ущерба людям и имуществу, потому что самые критические режимы проверяются вашим Ограничителем, а если вы ещё и внедрили Монитор Безопасности, то теперь злоумышленнику гораздо сложнее атаковать внутренние блоки, даже если он смог проникнуть в какую-то бортовую систему или внедрить вредоносный код.
#
# Осталось проверить эффективность получившейся защиты на полной трассе - в этом и заключается модуль 4 задания, для перехода к которому нужно открыть блокнот с именем cyberimmunity--autonomous-car-m4. Успеха!
